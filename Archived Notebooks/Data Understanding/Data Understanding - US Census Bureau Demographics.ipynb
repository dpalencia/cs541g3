# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("../../datasets/ACSDP1Y2018.DP05_data_with_overlays_2020-09-15T163409.csv", encoding="latin1")

# %%
data.head()
# Out:
#           GEO_ID                                               NAME  \
# 0             id                               Geographic Area Name
# 1  5001600US0107  Congressional District 7 (116th Congress), Ala...
# 2  5001600US0605  Congressional District 5 (116th Congress), Cal...
# 3  5001600US0608  Congressional District 8 (116th Congress), Cal...
# 4  5001600US0618  Congressional District 18 (116th Congress), Ca...
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                   660468
# 2                                   730955
# 3                                   717107
# 4                                   750295
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                           11651
# 2                                            8907
# 3                                           10856
# ...
