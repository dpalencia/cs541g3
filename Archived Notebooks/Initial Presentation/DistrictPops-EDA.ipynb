# %%
import pandas as pd
import numpy as np

# %%
districtData = pd.read_csv("./Datasets/popsByDistricts.csv", header=1)

# %%
districtData.head()
# Out:
#               id                               Geographic Area Name  \
# 0  5001600US0107  Congressional District 7 (116th Congress), Ala...
# 1  5001600US0605  Congressional District 5 (116th Congress), Cal...
# 2  5001600US0608  Congressional District 8 (116th Congress), Cal...
# 3  5001600US0618  Congressional District 18 (116th Congress), Ca...
# 4  5001600US0622  Congressional District 22 (116th Congress), Ca...
#
#    Estimate!!SEX AND AGE!!Total population  \
# 0                                   660468
# 1                                   730955
# 2                                   717107
# 3                                   750295
# 4                                   771095
#
#   Margin of Error!!SEX AND AGE!!Total population  \
# 0                                          11651
# 1                                           8907
# 2                                          10856
# 3                                          13343
# ...

# %%
districtData.drop(0)
# Out:
#             GEO_ID                                               NAME  \
# 1    5001600US0107  Congressional District 7 (116th Congress), Ala...
# 2    5001600US0605  Congressional District 5 (116th Congress), Cal...
# 3    5001600US0608  Congressional District 8 (116th Congress), Cal...
# 4    5001600US0618  Congressional District 18 (116th Congress), Ca...
# 5    5001600US0622  Congressional District 22 (116th Congress), Ca...
# ..             ...                                                ...
# 433  5001600US4702  Congressional District 2 (116th Congress), Ten...
# 434  5001600US4816  Congressional District 16 (116th Congress), Texas
# 435  5001600US4834  Congressional District 34 (116th Congress), Texas
# 436  5001600US5101  Congressional District 1 (116th Congress), Vir...
# 437  5001600US5402  Congressional District 2 (116th Congress), Wes...
#
#     DP05_0001E DP05_0001M DP05_0001PE DP05_0001PM DP05_0002E DP05_0002M  \
# ...

# %%
pd.options.display.max_seq_items = 2000
print(districtData.columns)
# Out:
# Index(['id', 'Geographic Area Name', 'Estimate!!SEX AND AGE!!Total population',
#        'Margin of Error!!SEX AND AGE!!Total population',
#        'Percent Estimate!!SEX AND AGE!!Total population',
#        'Percent Margin of Error!!SEX AND AGE!!Total population',
#        'Estimate!!SEX AND AGE!!Total population!!Male',
#        'Margin of Error!!SEX AND AGE!!Total population!!Male',
#        'Percent Estimate!!SEX AND AGE!!Total population!!Male',
#        'Percent Margin of Error!!SEX AND AGE!!Total population!!Male',
#        'Estimate!!SEX AND AGE!!Total population!!Female',
#        'Margin of Error!!SEX AND AGE!!Total population!!Female',
#        'Percent Estimate!!SEX AND AGE!!Total population!!Female',
#        'Percent Margin of Error!!SEX AND AGE!!Total population!!Female',
#        'Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
#        'Margin of Error!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
# ...

# %%
caliBools = ["California" in s for s in districtData["Geographic Area Name"]]
californiaDistricts = districtData[caliBools]
californiaDistricts.head()
# Out:
#               id                               Geographic Area Name  \
# 1  5001600US0605  Congressional District 5 (116th Congress), Cal...
# 2  5001600US0608  Congressional District 8 (116th Congress), Cal...
# 3  5001600US0618  Congressional District 18 (116th Congress), Ca...
# 4  5001600US0622  Congressional District 22 (116th Congress), Ca...
# 5  5001600US0634  Congressional District 34 (116th Congress), Ca...
#
#    Estimate!!SEX AND AGE!!Total population  \
# 1                                   730955
# 2                                   717107
# 3                                   750295
# 4                                   771095
# 5                                   748812
#
#   Margin of Error!!SEX AND AGE!!Total population  \
# 1                                           8907
# 2                                          10856
# 3                                          13343
# 4                                          14653
# ...

# %%
len(californiaDistricts["Geographic Area Name"])
# Out:
# 53
